# %%
import random as rd
print("Welcome to Power Ball Simulator App!")
white_ball=int(input("Enter the number of white-balls for 5 winning numbers (Normally 69): "))
red_ball=int(input("Enter the number of red-balls for the Power ball (Normally 26): "))
probability=white_ball*(white_ball-1)*(white_ball-2)*(white_ball-3)*(white_ball-4)/120
print(f"The probability of winning is 1 in {probability} intervals !!!")
n=int(input("Purchase the tickets in what intervals: "))
unique=[]
if white_ball>4 and white_ball<70:
    if red_ball>0 and red_ball<27:
        random_white=[]
        random_outcome=[]
        random_red=rd.randint(1,26)
        for num in range(5):
            j=rd.randint(1,69)
            while j in random_white:
                j = rd.randint(1, 69)
            random_white.append(j)
            random_white.sort()
            random_outcome=random_white[:]
        random_outcome.append(random_red)
        for i in range(n):
            user_white=[]
            user_outcome=[]
            user_red=rd.randint(1,red_ball+1)
            for nu in range(5):
                k=rd.randint(1,white_ball)
                while k in user_white:
                    k = rd.randint(1, white_ball)
                user_white.append(k)
                user_white.sort()
                user_outcome=user_white[:]
            user_outcome.append(user_red)
            if user_outcome not in unique:
                unique.append(user_outcome)
            else:
                print("the value already occured")
            print(user_outcome,random_outcome,i)
            if random_outcome==user_outcome:
                print("You've won the game after "+str(i)+" internals")
                break
            else:
                pass
# Out:
# Welcome to Power Ball Simulator App!
# Enter the number of white-balls for 5 winning numbers (Normally 69): 69
# Enter the number of red-balls for the Power ball (Normally 26): 26
# The probability of winning is 1 in 11238513.0 intervals !!!
# Purchase the tickets in what intervals: 1000
# [3, 13, 28, 46, 55, 19] [18, 28, 42, 48, 65, 20] 0
# [5, 41, 42, 65, 67, 25] [18, 28, 42, 48, 65, 20] 1
# [7, 27, 58, 62, 63, 13] [18, 28, 42, 48, 65, 20] 2
# [2, 10, 55, 57, 61, 12] [18, 28, 42, 48, 65, 20] 3
# [26, 44, 49, 67, 68, 4] [18, 28, 42, 48, 65, 20] 4
# [16, 48, 50, 57, 65, 20] [18, 28, 42, 48, 65, 20] 5
# [3, 20, 46, 53, 54, 8] [18, 28, 42, 48, 65, 20] 6
# [1, 28, 42, 53, 56, 14] [18, 28, 42, 48, 65, 20] 7
# [2, 9, 38, 54, 55, 23] [18, 28, 42, 48, 65, 20] 8
# [8, 9, 10, 24, 59, 18] [18, 28, 42, 48, 65, 20] 9
# [4, 34, 43, 50, 62, 4] [18, 28, 42, 48, 65, 20] 10
# [12, 15, 30, 46, 47, 7] [18, 28, 42, 48, 65, 20] 11
# [8, 10, 44, 59, 61, 21] [18, 28, 42, 48, 65, 20] 12
# ...
